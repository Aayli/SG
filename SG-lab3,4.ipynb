# %%
import os
import librosa
from matplotlib import pyplot
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile
import warnings
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import make_scorer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
from tensorflow import keras
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
from keras.models import load_model


warnings.filterwarnings("ignore")
# Out:
# 2021-11-03 15:55:33.695393: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-03 15:55:33.695439: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
labels=["yes", "no", "on", "off", "stop"]

# %%
train_audio_path = '/home/wojtek/SG/speech_classification/'

all_wave = []
all_label = []
for label in labels:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000): 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# yes
# no
# on
# off
# stop

# %%
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
y=np_utils.to_categorical(y, num_classes=len(labels))

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='accurancy', verbose=1, save_best_only=True, mode='max')

# %%
def predict(audio, model):
    indices = np.empty(len(y_val))
    e = 0
    for i in audio:
        prob=model.predict(i.reshape(-1,8000,1))
        index=np.argmax(prob[0])
        indices[e]=index
        e += 1
    return indices
    #return classes[index]

# %%
import logging
import tensorflow as tf
tf.get_logger().setLevel('INFO')
tf.get_logger().setLevel(logging.ERROR)

x_train, x_valid, y_train, y_valid = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)
k = [(len(x_train), len(x_valid)), (3*len(x_train)//4,3*len(x_valid)//4), (2*len(x_train)//3, 2*len(x_valid)//3), (len(x_train)//2, len(x_valid)//2), (len(x_train)//3, len(x_valid)//3), (len(x_train)//4, len(x_valid)//4), (len(x_train)//5, len(x_valid)//5)]

precision_summary =[]
recall_summary = []
f1_summary = []

for (i, j) in k:
    
    K.clear_session()
    inputs = Input(shape=(8000,1))
    #First Conv1D layer
    conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)
    #Second Conv1D layer
    conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)
    #Third Conv1D layer
    conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)
    #Fourth Conv1D layer
    conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
    conv = MaxPooling1D(3)(conv)
    conv = Dropout(0.3)(conv)
    #Flatten layer
    conv = Flatten()(conv)
    #Dense Layer 1
    conv = Dense(256, activation='relu')(conv)
    conv = Dropout(0.3)(conv)
    #Dense Layer 2
    conv = Dense(128, activation='relu')(conv)
    conv = Dropout(0.3)(conv)
    outputs = Dense(len(labels), activation='softmax')(conv)
    
    model = Model(inputs, outputs)
    #model.summary()
    model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
    
    x_tr = x_train[:i]
    y_tr = y_train[:i]
    x_val = x_valid[:j]
    y_val = y_valid[:j]
    history = model.fit(x_tr, y_tr ,epochs=3, verbose=0, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
    y_pred = predict(x_val, model)
    y_val_max = np.argmax(y_val, axis=1)
    confmat = confusion_matrix(y_true=y_val_max, y_pred=y_pred)
    print("\n---------------------------------------------------------------------------------------------------------------------\n")
    print("\n\nMacierz pomylek dla zbioru treningowego {} oraz zbioru walidacyjnego {}: \n\n{}".format(i,j,confmat))

    precision_macro = precision_score(y_true=y_val_max, y_pred=y_pred, average='macro')
    precision_summary.append(precision_macro)
    recall_macro = recall_score(y_true=y_val_max, y_pred=y_pred, average='macro')
    recall_summary.append(recall_macro)
    f1_macro = f1_score(y_true=y_val_max, y_pred=y_pred, average='macro')
    f1_summary.append(f1_macro)
    print("\nPrecyzja dla zbioru treningowego {} oraz zbioru walidacyjnego {}: {}".format(i, j, precision_macro))
    print("\nPelnosc dla zbioru treningowego {} oraz zbioru walidacyjnego {}: {}".format(i, j, recall_macro))
    print("\nF1 dla zbioru treningowego {} oraz zbioru walidacyjnego {}: {}".format(i, j, f1_macro))

    precision = precision_score(y_true=y_val_max, y_pred=y_pred, average=None)
    recall = recall_score(y_true=y_val_max, y_pred=y_pred, average=None)
    f1 = f1_score(y_true=y_val_max, y_pred=y_pred, average=None)

    barWidth = 0.25
    fig = plt.figure()
    br1 = np.arange(len(precision))
    br2 = [x + barWidth for x in br1]
    br3 = [x + barWidth for x in br2]
    plt.bar(br1, precision, color='r', width=barWidth, label='Precyzja')
    plt.bar(br2, recall, color='g', width=barWidth, label='Pelnosc')
    plt.bar(br3, f1, color='b', width=barWidth, label='F1')
    plt.xticks([r+barWidth for r in range(len(precision))], [classes[0], classes[1], classes[2], classes[3], classes[4]]) 
    plt.legend()
    plt.title("\nDla zbioru treningowego: {} oraz zbioru walidacyjnego: {}".format(i, j))
    plt.show()
# Out:
# 2021-11-03 15:58:58.589017: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2021-11-03 15:58:58.589068: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-11-03 15:58:58.589092: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (wojtek): /proc/driver/nvidia/version does not exist
# 2021-11-03 15:58:58.589492: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-03 15:58:58.722142: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 273312000 exceeds 10% of free system memory.
# 2021-11-03 15:58:59.112798: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Macierz pomylek dla zbioru treningowego 8541 oraz zbioru walidacyjnego 2136:
#
# [[218   1   3  21 177]
#  [  0 322  14  68  25]
#  [ 10  54 304  12  41]
#  [  4  18   2 368  43]
#  [  2   0   0  11 418]]
#
# Precyzja dla zbioru treningowego 8541 oraz zbioru walidacyjnego 2136: 0.809681388459311
#
# Pelnosc dla zbioru treningowego 8541 oraz zbioru walidacyjnego 2136: 0.7615070458828487
#
# F1 dla zbioru treningowego 8541 oraz zbioru walidacyjnego 2136: 0.7612719654303247
# 2021-11-03 16:02:35.998930: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 204960000 exceeds 10% of free system memory.
# Macierz pomylek dla zbioru treningowego 6405 oraz zbioru walidacyjnego 1602:
#
# [[ 87   1  11  30 179]
#  [  0 208  36  65  19]
#  [  3  50 216  28  22]
#  [ 20  12   5 248  35]
#  [  6   0   6  15 300]]
#
# Precyzja dla zbioru treningowego 6405 oraz zbioru walidacyjnego 1602: 0.6977752860665258
#
# Pelnosc dla zbioru treningowego 6405 oraz zbioru walidacyjnego 1602: 0.6572322108104626
#
# F1 dla zbioru treningowego 6405 oraz zbioru walidacyjnego 1602: 0.6432378034529309
# 2021-11-03 16:05:25.117270: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 182208000 exceeds 10% of free system memory.
# Macierz pomylek dla zbioru treningowego 5694 oraz zbioru walidacyjnego 1424:
#
# [[ 97   0   0  33 148]
#  [  2 194  13  70  14]
#  [  5 147  64  32  29]
#  [ 38   5   0 221  27]
#  [  8   0   0   9 268]]
#
# Precyzja dla zbioru treningowego 5694 oraz zbioru walidacyjnego 1424: 0.6390897841453792
#
# Pelnosc dla zbioru treningowego 5694 oraz zbioru walidacyjnego 1424: 0.5883769769374428
#
# F1 dla zbioru treningowego 5694 oraz zbioru walidacyjnego 1424: 0.5582066444807048
# 2021-11-03 16:07:55.572650: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 136640000 exceeds 10% of free system memory.
# Macierz pomylek dla zbioru treningowego 4270 oraz zbioru walidacyjnego 1068:
#
# [[136   0   6  26  40]
#  [  0 132  15  82   2]
#  [  2  18 164  21   3]
#  [  5  39   3 157  11]
#  [ 36   0   2  25 143]]
#
# Precyzja dla zbioru treningowego 4270 oraz zbioru walidacyjnego 1068: 0.7089526490823824
#
# Pelnosc dla zbioru treningowego 4270 oraz zbioru walidacyjnego 1068: 0.6876287158314704
#
# F1 dla zbioru treningowego 4270 oraz zbioru walidacyjnego 1068: 0.6917330846517202
# 2021-11-03 16:09:44.022445: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 91104000 exceeds 10% of free system memory.
# Macierz pomylek dla zbioru treningowego 2847 oraz zbioru walidacyjnego 712:
#
# [[ 14   0   2  21  87]
#  [  0  74   7  78   2]
#  [  2  24  66  24  16]
#  [  1   7   1 131  12]
#  [  3   0   2  25 113]]
#
# Precyzja dla zbioru treningowego 2847 oraz zbioru walidacyjnego 712: 0.6423508297842099
#
# Pelnosc dla zbioru treningowego 2847 oraz zbioru walidacyjnego 712: 0.5449164900943894
#
# F1 dla zbioru treningowego 2847 oraz zbioru walidacyjnego 712: 0.5186387209748732
# Macierz pomylek dla zbioru treningowego 2135 oraz zbioru walidacyjnego 534:
#
# [[ 5  1  0  7 92]
#  [ 2 27 21 25 40]
#  [ 3 21 32 14 33]
#  [ 1  3  1 39 62]
#  [ 0  0  0  6 99]]
#
# Precyzja dla zbioru treningowego 2135 oraz zbioru walidacyjnego 534: 0.4597242453070674
#
# Pelnosc dla zbioru treningowego 2135 oraz zbioru walidacyjnego 534: 0.38077258782484297
#
# F1 dla zbioru treningowego 2135 oraz zbioru walidacyjnego 534: 0.33450786802027277
# Macierz pomylek dla zbioru treningowego 1708 oraz zbioru walidacyjnego 427:
#
# [[21  1  0  5 58]
#  [14 31  5 25 17]
#  [ 9 28  7 24 16]
#  [21  7  0 31 19]
#  [ 5  0  0  5 78]]
#
# Precyzja dla zbioru treningowego 1708 oraz zbioru walidacyjnego 427: 0.42107159239264674
#
# Pelnosc dla zbioru treningowego 1708 oraz zbioru walidacyjnego 427: 0.39022964248028186
#
# F1 dla zbioru treningowego 1708 oraz zbioru walidacyjnego 427: 0.3482006385078046

# %%
x = []
for (i,j) in k:
    x.append(i+j)
plt.plot(x, f1_summary, 'r', label='f1') 
plt.plot(x, recall_summary, 'b', label='pelnosc')
plt.plot(x, precision_summary, 'g', label='precyzja')
plt.legend()
plt.xlabel("Liczebnosc zbioru")
plt.show()

# %%
#from keras.models import load_model
#model=load_model('best_model.hdf5')
